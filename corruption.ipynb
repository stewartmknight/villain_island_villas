# %%
import pandas as pd

# %%
# Read the data source
df = pd.read_excel("Resources/18_FullDataSet.xlsx")

# %%
# Display to make sure everything looks good
df
# Out:
#           Country ISO3 Region  CPI Score 2018  Rank   Standard error  \
# 0         Denmark  DNK  WE/EU              88      1            2.63
# 1     New Zealand  NZL     AP              87      2            2.44
# 2         Finland  FIN  WE/EU              85      3            2.74
# 3       Singapore  SGP     AP              85      3            1.98
# 4          Sweden  SWE  WE/EU              85      3            2.02
# ..            ...  ...    ...             ...    ...             ...
# 175  Korea, North  PRK     AP              14    176            1.39
# 176         Yemen  YEM   MENA              14    176            1.45
# 177   South Sudan  SSD    SSA              13    178            1.86
# 178         Syria  SYR   MENA              13    178            1.92
# 179       Somalia  SOM    SSA              10    180            3.08
#
#      Number of sources  Upper CI  Lower CI   African Development Bank CPIA  \
# ...

# %%
# Get only the columns I need
df=df[["Country", "CPI Score 2018", "Standard error"]]
df
# Out:
#           Country  CPI Score 2018  Standard error
# 0         Denmark              88            2.63
# 1     New Zealand              87            2.44
# 2         Finland              85            2.74
# 3       Singapore              85            1.98
# 4          Sweden              85            2.02
# ..            ...             ...             ...
# 175  Korea, North              14            1.39
# 176         Yemen              14            1.45
# 177   South Sudan              13            1.86
# 178         Syria              13            1.92
# 179       Somalia              10            3.08
#
# [180 rows x 3 columns]

# %%
# Send to CSV file
df.to_csv("Output/Cleaned_Corruption.csv")
